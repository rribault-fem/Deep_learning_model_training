# %%
import xarray as xr
xr.open_dataset(r"C:\Users\romain.ribault\Documents\git_folders\torchydra\data\netcdf_databases\20231019_for_torchydra_ins_to_tension.nc")
# Out:
# <xarray.Dataset>
# Dimensions:                      (time: 2204, time_sensor: 36000,
#                                   time_psd: 3552, Frequency_psd: 857,
#                                   efth_dir: 24, efth_freq: 32)
# Coordinates:
#   * time                         (time) datetime64[ns] 2023-02-19 ... 2023-07...
#   * time_sensor                  (time_sensor) float64 0.0 0.1 ... 3.6e+03
#   * time_psd                     (time_psd) datetime64[ns] 2023-02-19 ... 202...
#   * Frequency_psd                (Frequency_psd) float64 0.0 0.005013 ... 4.0
# Dimensions without coordinates: efth_dir, efth_freq
# Data variables: (12/67)
#     NCD_5_line_A                 (time, time_sensor) float64 ...
#     NCD_5_line_A_psd             (time_psd, Frequency_psd) float64 ...
#     NCD_6_line_A                 (time, time_sensor) float64 ...
#     NCD_6_line_A_psd             (time_psd, Frequency_psd) float64 ...
#     NCD_8_line_B                 (time, time_sensor) float64 ...
# ...
